# %%
import numpy as np

import pandas as pd

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])

# %%
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range('20130101', periods=6)

# %%
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(6, 4), index=dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.082476  0.894384  0.536247 -1.302728
# 2013-01-02  1.045480 -1.034697  0.583114 -0.394479
# 2013-01-03  0.471688 -0.321749  0.692183 -0.324958
# 2013-01-04 -0.154961 -0.899122  0.545056 -0.100424
# 2013-01-05 -0.395865  0.823646 -0.232593 -0.682287
# 2013-01-06  1.450143 -0.919190  2.318016  0.255521

# %%
df2 = pd.DataFrame({'A': 1.,
'B': pd.Timestamp('20130102'),
'C': pd.Series(1, index=list(range(4)), dtype='float32'),
'D': np.array([3] * 4, dtype='int32'),
'E': pd.Categorical(["test", "train", "test", "train"]),
'F': 'foo'})

# %%
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df2.abs
# Out:
# <bound method NDFrame.abs of      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo>

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01  0.082476  0.894384  0.536247 -1.302728
# 2013-01-02  1.045480 -1.034697  0.583114 -0.394479
# 2013-01-03  0.471688 -0.321749  0.692183 -0.324958
# 2013-01-04 -0.154961 -0.899122  0.545056 -0.100424
# 2013-01-05 -0.395865  0.823646 -0.232593 -0.682287

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2013-01-04 -0.154961 -0.899122  0.545056 -0.100424
# 2013-01-05 -0.395865  0.823646 -0.232593 -0.682287
# 2013-01-06  1.450143 -0.919190  2.318016  0.255521

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.to_numpy()
# Out:
# array([[ 0.08247583,  0.89438411,  0.53624734, -1.3027275 ],
#        [ 1.04548031, -1.03469703,  0.58311434, -0.39447907],
#        [ 0.47168809, -0.32174888,  0.69218313, -0.32495799],
#        [-0.15496071, -0.89912241,  0.54505605, -0.10042409],
#        [-0.39586504,  0.82364559, -0.23259288, -0.68228697],
#        [ 1.45014349, -0.91919028,  2.318016  ,  0.25552069]])

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2013-01-02 00:00:00'), 1.0, 3, 'train', 'foo']],
#       dtype=object)

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.416494 -0.242788  0.740337 -0.424892
# std    0.716262  0.889055  0.841723  0.532165
# min   -0.395865 -1.034697 -0.232593 -1.302728
# 25%   -0.095602 -0.914173  0.538450 -0.610335
# 50%    0.277082 -0.610436  0.564085 -0.359719
# 75%    0.902032  0.537297  0.664916 -0.156558
# max    1.450143  0.894384  2.318016  0.255521

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06
# A    0.082476    1.045480    0.471688   -0.154961   -0.395865    1.450143
# B    0.894384   -1.034697   -0.321749   -0.899122    0.823646   -0.919190
# C    0.536247    0.583114    0.692183    0.545056   -0.232593    2.318016
# D   -1.302728   -0.394479   -0.324958   -0.100424   -0.682287    0.255521

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2013-01-01 -1.302728  0.536247  0.894384  0.082476
# 2013-01-02 -0.394479  0.583114 -1.034697  1.045480
# 2013-01-03 -0.324958  0.692183 -0.321749  0.471688
# 2013-01-04 -0.100424  0.545056 -0.899122 -0.154961
# 2013-01-05 -0.682287 -0.232593  0.823646 -0.395865
# 2013-01-06  0.255521  2.318016 -0.919190  1.450143

# %%
df.sort_values(by='B')
# Out:
#                    A         B         C         D
# 2013-01-02  1.045480 -1.034697  0.583114 -0.394479
# 2013-01-06  1.450143 -0.919190  2.318016  0.255521
# 2013-01-04 -0.154961 -0.899122  0.545056 -0.100424
# 2013-01-03  0.471688 -0.321749  0.692183 -0.324958
# 2013-01-05 -0.395865  0.823646 -0.232593 -0.682287
# 2013-01-01  0.082476  0.894384  0.536247 -1.302728

# %%
df['A']
# Out:
# 2013-01-01    0.082476
# 2013-01-02    1.045480
# 2013-01-03    0.471688
# 2013-01-04   -0.154961
# 2013-01-05   -0.395865
# 2013-01-06    1.450143
# Freq: D, Name: A, dtype: float64

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01  0.082476  0.894384  0.536247 -1.302728
# 2013-01-02  1.045480 -1.034697  0.583114 -0.394479
# 2013-01-03  0.471688 -0.321749  0.692183 -0.324958

# %%
df['20130102':'20130104']
# Out:
#                    A         B         C         D
# 2013-01-02  1.045480 -1.034697  0.583114 -0.394479
# 2013-01-03  0.471688 -0.321749  0.692183 -0.324958
# 2013-01-04 -0.154961 -0.899122  0.545056 -0.100424

# %%
df.loc[dates[0]]
# Out:
# A    0.082476
# B    0.894384
# C    0.536247
# D   -1.302728
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
df.loc[:, ['A', 'B']]
# Out:
#                    A         B
# 2013-01-01  0.082476  0.894384
# 2013-01-02  1.045480 -1.034697
# 2013-01-03  0.471688 -0.321749
# 2013-01-04 -0.154961 -0.899122
# 2013-01-05 -0.395865  0.823646
# 2013-01-06  1.450143 -0.919190

# %%
df.loc['20130102':'20130104', ['A', 'B']]
# Out:
#                    A         B
# 2013-01-02  1.045480 -1.034697
# 2013-01-03  0.471688 -0.321749
# 2013-01-04 -0.154961 -0.899122

# %%
df.loc['20130102', ['A', 'B']]
# Out:
# A    1.045480
# B   -1.034697
# Name: 2013-01-02 00:00:00, dtype: float64

# %%
df.loc[dates[0], 'A']
# Out:
# 0.0824758319900826

# %%
df.at[dates[0], 'A']
# Out:
# 0.0824758319900826

# %%
df.iloc[3]
# Out:
# A   -0.154961
# B   -0.899122
# C    0.545056
# D   -0.100424
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2013-01-04 -0.154961 -0.899122
# 2013-01-05 -0.395865  0.823646

# %%
df.iloc[[1, 2, 4], [0, 2]]
# Out:
#                    A         C
# 2013-01-02  1.045480  0.583114
# 2013-01-03  0.471688  0.692183
# 2013-01-05 -0.395865 -0.232593

# %%
In [35]: df.iloc[1:3, :]
# Out:
#                    A         B         C         D
# 2013-01-02  1.045480 -1.034697  0.583114 -0.394479
# 2013-01-03  0.471688 -0.321749  0.692183 -0.324958

# %%
df.iloc[:, 1:3]
# Out:
#                    B         C
# 2013-01-01  0.894384  0.536247
# 2013-01-02 -1.034697  0.583114
# 2013-01-03 -0.321749  0.692183
# 2013-01-04 -0.899122  0.545056
# 2013-01-05  0.823646 -0.232593
# 2013-01-06 -0.919190  2.318016

# %%
df.iloc[1, 1]
# Out:
# -1.0346970286809458

# %%
df.iat[1, 1]
# Out:
# -1.0346970286809458

# %%
df[df['A'] > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.082476  0.894384  0.536247 -1.302728
# 2013-01-02  1.045480 -1.034697  0.583114 -0.394479
# 2013-01-03  0.471688 -0.321749  0.692183 -0.324958
# 2013-01-06  1.450143 -0.919190  2.318016  0.255521

# %%
df[df > 0]
# Out:
#                    A         B         C         D
# 2013-01-01  0.082476  0.894384  0.536247       NaN
# 2013-01-02  1.045480       NaN  0.583114       NaN
# 2013-01-03  0.471688       NaN  0.692183       NaN
# 2013-01-04       NaN       NaN  0.545056       NaN
# 2013-01-05       NaN  0.823646       NaN       NaN
# 2013-01-06  1.450143       NaN  2.318016  0.255521

# %%
df2 = df.copy()

# %%
df2['E'] = ['one', 'one', 'two', 'three', 'four', 'three']

# %%
df2
# Out:
#                    A         B         C         D      E
# 2013-01-01  0.082476  0.894384  0.536247 -1.302728    one
# 2013-01-02  1.045480 -1.034697  0.583114 -0.394479    one
# 2013-01-03  0.471688 -0.321749  0.692183 -0.324958    two
# 2013-01-04 -0.154961 -0.899122  0.545056 -0.100424  three
# 2013-01-05 -0.395865  0.823646 -0.232593 -0.682287   four
# 2013-01-06  1.450143 -0.919190  2.318016  0.255521  three

# %%
s1 = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range('20130102', periods=6))

# %%
df['F'] = s1

# %%
df.at[dates[0], 'A'] = 0

# %%
df.iat[0, 1] = 0

# %%
df.loc[:, 'D'] = np.array([5] * len(df))

# %%
df2 = df.copy()

# %%
df2[df2 > 0] = -df2

# %%
df2
# Out:
#                    A         B         C  D    F
# 2013-01-01  0.000000  0.000000 -0.536247 -5  NaN
# 2013-01-02 -1.045480 -1.034697 -0.583114 -5 -1.0
# 2013-01-03 -0.471688 -0.321749 -0.692183 -5 -2.0
# 2013-01-04 -0.154961 -0.899122 -0.545056 -5 -3.0
# 2013-01-05 -0.395865 -0.823646 -0.232593 -5 -4.0
# 2013-01-06 -1.450143 -0.919190 -2.318016 -5 -5.0

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ['E'])

# %%
df1.loc[dates[0]:dates[1], 'E'] = 1

# %%
df1
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000  0.536247  5  NaN  1.0
# 2013-01-02  1.045480 -1.034697  0.583114  5  1.0  1.0
# 2013-01-03  0.471688 -0.321749  0.692183  5  2.0  NaN
# 2013-01-04 -0.154961 -0.899122  0.545056  5  3.0  NaN

# %%
df1.dropna(how='any')
# Out:
#                   A         B         C  D    F    E
# 2013-01-02  1.04548 -1.034697  0.583114  5  1.0  1.0

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C  D    F    E
# 2013-01-01  0.000000  0.000000  0.536247  5  5.0  1.0
# 2013-01-02  1.045480 -1.034697  0.583114  5  1.0  1.0
# 2013-01-03  0.471688 -0.321749  0.692183  5  2.0  5.0
# 2013-01-04 -0.154961 -0.899122  0.545056  5  3.0  5.0

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D      F      E
# 2013-01-01  False  False  False  False   True  False
# 2013-01-02  False  False  False  False  False  False
# 2013-01-03  False  False  False  False  False   True
# 2013-01-04  False  False  False  False  False   True

# %%
df.mean()
# Out:
# A    0.402748
# B   -0.391852
# C    0.740337
# D    5.000000
# F    3.000000
# dtype: float64

# %%
df.mean(1)
# Out:
# 2013-01-01    1.384062
# 2013-01-02    1.318780
# 2013-01-03    1.568424
# 2013-01-04    1.498195
# 2013-01-05    1.839038
# 2013-01-06    2.569794
# Freq: D, dtype: float64

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8], index=dates).shift(2)

# %%
s
# Out:
# 2013-01-01    NaN
# 2013-01-02    NaN
# 2013-01-03    1.0
# 2013-01-04    3.0
# 2013-01-05    5.0
# 2013-01-06    NaN
# Freq: D, dtype: float64

# %%
df.sub(s, axis='index')
# Out:
#                    A         B         C    D    F
# 2013-01-01       NaN       NaN       NaN  NaN  NaN
# 2013-01-02       NaN       NaN       NaN  NaN  NaN
# 2013-01-03 -0.528312 -1.321749 -0.307817  4.0  1.0
# 2013-01-04 -3.154961 -3.899122 -2.454944  2.0  0.0
# 2013-01-05 -5.395865 -4.176354 -5.232593  0.0 -1.0
# 2013-01-06       NaN       NaN       NaN  NaN  NaN

# %%
df.apply(np.cumsum)
# Out:
#                    A         B         C   D     F
# 2013-01-01  0.000000  0.000000  0.536247   5   NaN
# 2013-01-02  1.045480 -1.034697  1.119362  10   1.0
# 2013-01-03  1.517168 -1.356446  1.811545  15   3.0
# 2013-01-04  1.362208 -2.255568  2.356601  20   6.0
# 2013-01-05  0.966343 -1.431923  2.124008  25  10.0
# 2013-01-06  2.416486 -2.351113  4.442024  30  15.0

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# A    1.846009
# B    1.858343
# C    2.550609
# D    0.000000
# F    4.000000
# dtype: float64

# %%
s = pd.Series(np.random.randint(0, 7, size=10))

# %%
s
# Out:
# 0    3
# 1    2
# 2    4
# 3    5
# 4    5
# 5    6
# 6    0
# 7    3
# 8    1
# 9    1
# dtype: int64

# %%
s.value_counts()
# Out:
# 5    2
# 3    2
# 1    2
# 6    1
# 4    1
# 2    1
# 0    1
# dtype: int64

# %%
s = pd.Series(['A', 'B', 'C', 'Aaba', 'Baca', np.nan, 'CABA', 'dog', 'cat'])

# %%
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %%
df = pd.DataFrame(np.random.randn(10, 4))

# %%
df
# Out:
#           0         1         2         3
# 0  0.552574 -0.480300  0.273048  0.057027
# 1 -0.141610  0.003913  0.033754 -0.204111
# 2  0.176309 -0.749059 -0.323723 -1.741231
# 3  1.888256 -1.943320  0.711437 -1.313703
# 4 -0.680418  0.856679 -0.841024  0.008562
# 5 -0.680214  0.358823 -0.425048  1.020128
# 6 -1.656053  0.200396 -0.496875 -1.611213
# 7 -1.062693  0.519601 -0.437424 -0.531474
# 8 -1.276633 -3.077390  0.512295  0.236398
# 9  0.395731 -0.738739  1.323243 -1.219367

# %%
pieces = [df[:3], df[3:7], df[7:]]

# %%
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0  0.552574 -0.480300  0.273048  0.057027
# 1 -0.141610  0.003913  0.033754 -0.204111
# 2  0.176309 -0.749059 -0.323723 -1.741231
# 3  1.888256 -1.943320  0.711437 -1.313703
# 4 -0.680418  0.856679 -0.841024  0.008562
# 5 -0.680214  0.358823 -0.425048  1.020128
# 6 -1.656053  0.200396 -0.496875 -1.611213
# 7 -1.062693  0.519601 -0.437424 -0.531474
# 8 -1.276633 -3.077390  0.512295  0.236398
# 9  0.395731 -0.738739  1.323243 -1.219367

# %%
right = pd.DataFrame({'key': ['foo', 'foo'], 'rval': [4, 5]})

# %%
left = pd.DataFrame({'key': ['foo', 'foo'], 'lval': [1, 2]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left, right, on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
left = pd.DataFrame({'key': ['foo', 'bar'], 'lval': [1, 2]})

# %%
right = pd.DataFrame({'key': ['foo', 'bar'], 'rval': [4, 5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  bar     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  bar     5

# %%
pd.merge(left, right, on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  bar     2     5

# %%
df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar',
                           'foo', 'bar', 'foo', 'foo'],
                      'B': ['one', 'one', 'two', 'three',
                             'two', 'two', 'one', 'three'],
                       'C': np.random.randn(8),
                     'D': np.random.randn(8)})

# %%
df
# Out:
#      A      B         C         D
# 0  foo    one  0.304475 -1.211732
# 1  bar    one -0.801074 -0.499848
# 2  foo    two  0.016939 -0.179415
# 3  bar  three  0.008528 -0.870471
# 4  foo    two  0.731798  0.775593
# 5  bar    two  0.720746 -0.690325
# 6  foo    one  1.394057  0.711662
# 7  foo  three  0.858663 -0.549233

# %%
df.groupby('A').sum()
# Out:
#             C         D
# A
# bar -0.071799 -2.060644
# foo  3.305932 -0.453125

# %%
df.groupby(['A', 'B']).sum()
# Out:
#                   C         D
# A   B
# bar one   -0.801074 -0.499848
#     three  0.008528 -0.870471
#     two    0.720746 -0.690325
# foo one    1.698532 -0.500071
#     three  0.858663 -0.549233
#     two    0.748738  0.596179

# %%
tuples = list(zip(*[['bar', 'bar', 'baz', 'baz',
                       'foo', 'foo', 'qux', 'qux'],
                        ['one', 'two', 'one', 'two',
                        'one', 'two', 'one', 'two']]))

# %%
index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second'])

# %%
df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=['A', 'B'])

# %%
df2 = df[:4]

# %%
df2
# Out:
#                      A         B
# first second
# bar   one    -0.584913 -1.803666
#       two    -0.011199 -2.381343
# baz   one     0.908652  0.235280
#       two    -0.349032  0.591524

# %%
stacked = df2.stack()

# %%
stacked
# Out:
# first  second
# bar    one     A   -0.584913
#                B   -1.803666
#        two     A   -0.011199
#                B   -2.381343
# baz    one     A    0.908652
#                B    0.235280
#        two     A   -0.349032
#                B    0.591524
# dtype: float64

# %%
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one    -0.584913 -1.803666
#       two    -0.011199 -2.381343
# baz   one     0.908652  0.235280
#       two    -0.349032  0.591524

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A -0.584913 -0.011199
#       B -1.803666 -2.381343
# baz   A  0.908652 -0.349032
#       B  0.235280  0.591524

# %%
stacked.unstack(0)
# Out:
# first          bar       baz
# second
# one    A -0.584913  0.908652
#        B -1.803666  0.235280
# two    A -0.011199 -0.349032
#        B -2.381343  0.591524

# %%
 df = pd.DataFrame({'A': ['one', 'one', 'two', 'three'] * 3,
                       'B': ['A', 'B', 'C'] * 4,
                       'C': ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'] * 2,
                       'D': np.random.randn(12),
                      'E': np.random.randn(12)})

# %%
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo  0.114458  0.995611
# 1     one  B  foo -1.433399 -0.440986
# 2     two  C  foo  0.455175  0.460591
# 3   three  A  bar  1.428172 -0.192649
# 4     one  B  bar  0.572906  0.415002
# 5     one  C  bar -0.033423 -1.697018
# 6     two  A  foo  0.952494 -0.778703
# 7   three  B  foo  2.254103  1.240929
# 8     one  C  foo -0.162004  0.278033
# 9     one  A  bar -0.104241  0.398574
# 10    two  B  bar  1.606572  2.667006
# 11  three  C  bar -0.092636  0.187255

# %%
pd.pivot_table(df, values='D', index=['A', 'B'], columns=['C'])
# Out:
# C             bar       foo
# A     B
# one   A -0.104241  0.114458
#       B  0.572906 -1.433399
#       C -0.033423 -0.162004
# three A  1.428172       NaN
#       B       NaN  2.254103
#       C -0.092636       NaN
# two   A       NaN  0.952494
#       B  1.606572       NaN
#       C       NaN  0.455175

# %%
rng = pd.date_range('1/1/2012', periods=100, freq='S')

# %%
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)

# %%
ts.resample('5Min').sum()
# Out:
# 2012-01-01    25076
# Freq: 5T, dtype: int64

# %%
rng = pd.date_range('3/6/2012 00:00', periods=5, freq='D')

# %%
ts = pd.Series(np.random.randn(len(rng)), rng)

# %%
ts
# Out:
# 2012-03-06    0.383630
# 2012-03-07   -0.772755
# 2012-03-08   -0.109639
# 2012-03-09    1.517194
# 2012-03-10    0.861137
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize('UTC')

# %%
ts_utc
# Out:
# 2012-03-06 00:00:00+00:00    0.383630
# 2012-03-07 00:00:00+00:00   -0.772755
# 2012-03-08 00:00:00+00:00   -0.109639
# 2012-03-09 00:00:00+00:00    1.517194
# 2012-03-10 00:00:00+00:00    0.861137
# Freq: D, dtype: float64

# %%
ts_utc.tz_convert('US/Eastern')
# Out:
# 2012-03-05 19:00:00-05:00    0.383630
# 2012-03-06 19:00:00-05:00   -0.772755
# 2012-03-07 19:00:00-05:00   -0.109639
# 2012-03-08 19:00:00-05:00    1.517194
# 2012-03-09 19:00:00-05:00    0.861137
# Freq: D, dtype: float64

# %%
rng = pd.date_range('1/1/2012', periods=5, freq='M')

# %%
ts = pd.Series(np.random.randn(len(rng)), index=rng)

# %%
ts
# Out:
# 2012-01-31    0.408871
# 2012-02-29   -0.862638
# 2012-03-31    1.944777
# 2012-04-30   -0.399921
# 2012-05-31    0.966857
# Freq: M, dtype: float64

# %%
 ps = ts.to_period()

# %%
ps
# Out:
# 2012-01    0.408871
# 2012-02   -0.862638
# 2012-03    1.944777
# 2012-04   -0.399921
# 2012-05    0.966857
# Freq: M, dtype: float64

# %%
ps.to_timestamp()
# Out:
# 2012-01-01    0.408871
# 2012-02-01   -0.862638
# 2012-03-01    1.944777
# 2012-04-01   -0.399921
# 2012-05-01    0.966857
# Freq: MS, dtype: float64

# %%
prng = pd.period_range('1990Q1', '2000Q4', freq='Q-NOV')

# %%
ts = pd.Series(np.random.randn(len(prng)), prng)

# %%
ts.index = (prng.asfreq('M', 'e') + 1).asfreq('H', 's') + 9

# %%
ts.head()
# Out:
# 1990-03-01 09:00   -2.070093
# 1990-06-01 09:00   -0.485707
# 1990-09-01 09:00   -0.298253
# 1990-12-01 09:00    1.591495
# 1991-03-01 09:00   -0.489256
# Freq: H, dtype: float64

# %%
In [123]: df = pd.DataFrame({"id": [1, 2, 3, 4, 5, 6],
                       "raw_grade": ['a', 'b', 'b', 'a', 'a', 'e']})

# %%
df["grade"] = df["raw_grade"].astype("category")

# %%
df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): ['a', 'b', 'e']

# %%
df["grade"].cat.categories = ["very good", "good", "very bad"]

# %%
df["grade"] = df["grade"].cat.set_categories(["very bad", "bad", "medium",
                                                  "good", "very good"])

# %%
df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, object): ['very bad', 'bad', 'medium', 'good', 'very good']

# %%
df.sort_values(by="grade")
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %%
df.groupby("grade").size()
# Out:
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    3
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.close('all')

# %%
ts = pd.Series(np.random.randn(1000),
                  index=pd.date_range('1/1/2000', periods=1000))

# %%
ts = ts.cumsum()

# %%
ts.plot()

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index,
                   columns=['A', 'B', 'C', 'D'])

# %%
df = df.cumsum()

# %%
plt.figure()

# %%
df.plot()

# %%
plt.legend(loc='best')
# Out:
# No handles with labels found to put in legend.

# %%
df.to_csv('foo.csv')

# %%
pd.read_csv('foo.csv')
# Out:
#      Unnamed: 0          A         B          C          D
# 0    2000-01-01   1.024018 -1.421013   1.934121  -1.013052
# 1    2000-01-02   0.219910 -3.027470   2.976889  -1.955335
# 2    2000-01-03   1.878362 -3.686276   2.189341  -2.786819
# 3    2000-01-04   1.012876 -3.949125   2.957425  -3.042156
# 4    2000-01-05   1.690883 -4.516407   3.560276  -3.629198
# ..          ...        ...       ...        ...        ...
# 995  2002-09-22 -11.289062  8.676568  14.134375 -17.292225
# 996  2002-09-23 -12.882087  8.208729  14.992637 -17.711859
# 997  2002-09-24 -12.054676  8.057679  15.361288 -16.255333
# 998  2002-09-25 -11.841977  7.733685  15.333760 -16.109181
# 999  2002-09-26 -10.148609  7.097059  15.997503 -14.255427
#
# [1000 rows x 5 columns]

# %%
df.to_hdf('foo.h5', 'df')

# %%
pd.read_hdf('foo.h5', 'df')
# Out:
#                     A         B          C          D
# 2000-01-01   1.024018 -1.421013   1.934121  -1.013052
# 2000-01-02   0.219910 -3.027470   2.976889  -1.955335
# 2000-01-03   1.878362 -3.686276   2.189341  -2.786819
# 2000-01-04   1.012876 -3.949125   2.957425  -3.042156
# 2000-01-05   1.690883 -4.516407   3.560276  -3.629198
# ...               ...       ...        ...        ...
# 2002-09-22 -11.289062  8.676568  14.134375 -17.292225
# 2002-09-23 -12.882087  8.208729  14.992637 -17.711859
# 2002-09-24 -12.054676  8.057679  15.361288 -16.255333
# 2002-09-25 -11.841977  7.733685  15.333760 -16.109181
# 2002-09-26 -10.148609  7.097059  15.997503 -14.255427
#
# [1000 rows x 4 columns]

# %%
df.to_excel('foo.xlsx', sheet_name='Sheet1')

# %%
pd.read_excel('foo.xlsx', 'Sheet1', index_col=None, na_values=['NA'])
# Out:
#     Unnamed: 0          A         B          C          D
# 0   2000-01-01   1.024018 -1.421013   1.934121  -1.013052
# 1   2000-01-02   0.219910 -3.027470   2.976889  -1.955335
# 2   2000-01-03   1.878362 -3.686276   2.189341  -2.786819
# 3   2000-01-04   1.012876 -3.949125   2.957425  -3.042156
# 4   2000-01-05   1.690883 -4.516407   3.560276  -3.629198
# ..         ...        ...       ...        ...        ...
# 995 2002-09-22 -11.289062  8.676568  14.134375 -17.292225
# 996 2002-09-23 -12.882087  8.208729  14.992637 -17.711859
# 997 2002-09-24 -12.054676  8.057679  15.361288 -16.255333
# 998 2002-09-25 -11.841977  7.733685  15.333760 -16.109181
# 999 2002-09-26 -10.148609  7.097059  15.997503 -14.255427
#
# [1000 rows x 5 columns]
